# %% [markdown]
# # Challenge 2 Binary

# %%
number = 2025
binary = ""

while number != 0:
    remainder = number % 2
    binary = str(remainder) + binary
    number = number // 2

print(binary)
# Out:
# 11111101001
