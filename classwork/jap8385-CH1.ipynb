# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
x = np.linspace(0, 2*np.pi,50)


plt.subplot(2, 2, 1) # (row, column, active area)
plt.plot(x, np.sin(x), 'ms')


plt.subplot(2, 2, 2)
x1 = np.random.rand(500)
y1 = np.random.rand(500)
size = np.random.rand(500) * 100
color = np.random.rand(500)
plt.scatter(x1, y1, size, color)
plt.colorbar()

plt.subplot(2,2,3)
plt.plot(x, np.tan(x), 'r-o', label='Sin(x)')
plt.legend() 
plt.xlabel('Rads') 
plt.ylabel('Amplitude') 
plt.title('tangent') 

plt.subplot(2,2,4)
z1 = np.empty([2001,2001])
im = plt.imshow(z1, cmap='hot')
fig = plt.colorbar(im,
orientation='horizontal')
plt.show(fig)
i = 0
j = 0
t = 1
z = np.empty([2001,2001])
for x in np.arange(-10,10,.01):
    i = i + 1
    j = 0
    for y in np.arange(-10,10,.01):
        j = j + 1
        z[i][j] = x*x + y*y

plt.show()
