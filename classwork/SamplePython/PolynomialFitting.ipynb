# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)
x = np.linspace(-5,5,50)
y = 2 * x**2 + 3 * x + np.random.randn(50)*10

# %%
x
# Out:
# array([-5.        , -4.79591837, -4.59183673, -4.3877551 , -4.18367347,
#        -3.97959184, -3.7755102 , -3.57142857, -3.36734694, -3.16326531,
#        -2.95918367, -2.75510204, -2.55102041, -2.34693878, -2.14285714,
#        -1.93877551, -1.73469388, -1.53061224, -1.32653061, -1.12244898,
#        -0.91836735, -0.71428571, -0.51020408, -0.30612245, -0.10204082,
#         0.10204082,  0.30612245,  0.51020408,  0.71428571,  0.91836735,
#         1.12244898,  1.32653061,  1.53061224,  1.73469388,  1.93877551,
#         2.14285714,  2.34693878,  2.55102041,  2.75510204,  2.95918367,
#         3.16326531,  3.36734694,  3.57142857,  3.7755102 ,  3.97959184,
#         4.18367347,  4.3877551 ,  4.59183673,  4.79591837,  5.        ])

# %%
y
# Out:
# array([ 52.64052346,  35.61548295,  38.18179883,  47.75045636,
#         41.13080689,   9.96274807,  26.68330817,  13.28234628,
#         11.54382148,  14.62868389,  10.07642072,  21.45860346,
#         12.97272627,   5.19217707,   7.19373437,   5.0381177 ,
#         15.7550348 ,  -1.95787168,   2.67045211,  -9.38852091,
#        -26.59820303,   5.41373697,   7.63436615,  -8.15259564,
#         22.41224845, -14.21670964,   1.56337443,   0.17939015,
#         18.49105745,  19.13548691,   7.43660462,  11.28058396,
#          0.39952695,  -8.58555735,   9.854906  ,  17.17573459,
#         30.35996637,  32.69226996,  19.57321246,  23.36805954,
#         19.01676106,  18.57991226,  19.16178789,  59.34323917,
#         38.51655607,  43.17652479,  39.14010138,  63.72034296,
#         44.2504426 ,  62.8725972 ])

# %%
plt.scatter(x,y)

# %%
#Step 2: Polynomial fitting using NumPy's polyfit
# Fit a 2nd degree polynomial to the data

degree = 2 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Print the polynomial coefficients
print("Polynomial Coefficients: ", coefficients)

# Step 3: Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)
# Out:
# Polynomial Coefficients:  [2.09218103 1.58837751 0.60606342]

# %%
type(polynomial)
# Out:
# numpy.poly1d

# %%
# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)
# Step 4: Plotting the results
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
# Mean Squared Error (MSE)
mse = np.mean((y - y_pred)**2)
print(f'Mean Squared Error when {degree}: {mse:.4f}')
# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error when 2: 60.2974
# R-squared: 0.8469

# %%
#Step 2: Polynomial fitting using NumPy's polyfit
# Fit a 2nd degree polynomial to the data

degree = 20 # Degree of the polynomial
coefficients = np.polyfit(x, y, degree)

# Print the polynomial coefficients
print("Polynomial Coefficients: ", coefficients)

# Step 3: Use the coefficients to predict y-values (polynomial function)
# Generate polynomial function based on the coefficients
polynomial = np.poly1d(coefficients)
# Out:
# Polynomial Coefficients:  [ 5.22468852e-09  1.07230724e-07 -4.79836753e-07 -1.21522047e-05
#   1.57196267e-05  5.75494819e-04 -1.55223337e-04 -1.47563413e-02
#  -3.08864192e-03  2.21755630e-01  1.02222113e-01 -1.97249997e+00
#  -1.14995736e+00  9.94723916e+00  6.02252856e+00 -2.52392064e+01
#  -1.33475689e+01  2.31682255e+01  9.96250092e+00  3.48939399e+00
#   1.38455328e+00]

# %%
# Generate predicted y-values based on the fitted polynomial
y_pred = polynomial(x)
# Step 4: Plotting the results
plt.scatter(x, y, color='blue', label='Data points') # Original data points
plt.plot(x, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
# Mean Squared Error (MSE)
mse = np.mean((y - y_pred)**2)
print(f'Mean Squared Error when degree 20: {mse:.4f}')
# R-squared value
ss_total = np.sum((y - np.mean(y))**2)
ss_res = np.sum((y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Mean Squared Error when degree 20: 60.2974
# R-squared: 0.8469
