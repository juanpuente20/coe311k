# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 2*np.pi,50)

# %%
x
# Out:
# array([0.        , 0.12822827, 0.25645654, 0.38468481, 0.51291309,
#        0.64114136, 0.76936963, 0.8975979 , 1.02582617, 1.15405444,
#        1.28228272, 1.41051099, 1.53873926, 1.66696753, 1.7951958 ,
#        1.92342407, 2.05165235, 2.17988062, 2.30810889, 2.43633716,
#        2.56456543, 2.6927937 , 2.82102197, 2.94925025, 3.07747852,
#        3.20570679, 3.33393506, 3.46216333, 3.5903916 , 3.71861988,
#        3.84684815, 3.97507642, 4.10330469, 4.23153296, 4.35976123,
#        4.48798951, 4.61621778, 4.74444605, 4.87267432, 5.00090259,
#        5.12913086, 5.25735913, 5.38558741, 5.51381568, 5.64204395,
#        5.77027222, 5.89850049, 6.02672876, 6.15495704, 6.28318531])

# %%
plt.plot(x, np.sin(x),"r--", x, 2*np.sin(x),'g' )
plt.show()

# %%
plt.subplot(2,2,1) #row, column, active area
plt.plot (x, np.sin(x), 'b')
plt.subplot(2,2,2) #row, column, active area
plt.plot (x, np.cos(x), 'g')
plt.subplot(2,2,3) #row, column, active area
plt.plot (x, np.tan(x), 'k')
plt.subplot(2,2,4) #row, column, active area
plt.plot (x, np.arcsin(x), 'r')
plt.show
# Out:
# <ipython-input-41-3dbe57b691c0>:8: RuntimeWarning: invalid value encountered in arcsin
#   plt.plot (x, np.arcsin(x), 'r')
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.scatter(x,np.sin(x))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x = np.random.rand(1000)
y = np.random.rand(1000)
size = np.random.rand(1000) * 50
color = np.random.rand(1000)
plt.scatter(x, y, size, color)
plt.colorbar()
plt.show()

# %%
x = np.linspace(0, 2 * np.pi, 50)
plt.plot(x, np.sin(x), 'r-x', label='Sin(x)')
plt.plot(x, np.cos(x), 'g-^', label='Cos(x)')
plt.legend() # Display the legend.
plt.xlabel('Rads') # Add a label to the x-axis.
plt.ylabel('Amplitude') # Add a label to the y-axis.
plt.title('Sin and Cos Waves') # Add a graph title.
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
z1 = np.empty([2001,2001])
im = plt.imshow(z1, cmap='hot')
fig = plt.colorbar(im,
orientation='horizontal')
plt.show(fig)

# %%
i = 0
j = 0
t = 1
z = np.empty([2001,2001])
for x in np.arange(-10,10,.01):
    i = i + 1
    j = 0
    for y in np.arange(-10,10,.01):
        j = j + 1
        z[i][j] = x*x + y*y

# %%
z
# Out:
# array([[4.68570426e-310, 6.94469493e-310, 4.68570426e-310, ...,
#         7.81250185e-003, 7.81250185e-003, 7.81250185e-003],
#        [7.81250185e-003, 2.00000000e+002, 1.99800100e+002, ...,
#         1.99400900e+002, 1.99600400e+002, 1.99800100e+002],
#        [7.81250185e-003, 1.99800100e+002, 1.99600200e+002, ...,
#         1.99201000e+002, 1.99400500e+002, 1.99600200e+002],
#        ...,
#        [1.88888889e-001, 1.99400900e+002, 1.99201000e+002, ...,
#         1.98801800e+002, 1.99001300e+002, 1.99201000e+002],
#        [1.88888889e-001, 1.99600400e+002, 1.99400500e+002, ...,
#         1.99001300e+002, 1.99200800e+002, 1.99400500e+002],
#        [1.88888889e-001, 1.99800100e+002, 1.99600200e+002, ...,
#         1.99201000e+002, 1.99400500e+002, 1.99600200e+002]])

# %%
def f1(x,y):
    return (x*x+y*y)
x = np.linspace(-10, 10, 2000)
y = np.linspace(-10, 10, 2000)
X, Y = np.meshgrid(x, y)
Z = f1(X, Y)

# %%
Z
# Out:
# array([[200.        , 199.80000005, 199.6002003 , ..., 199.6002003 ,
#         199.80000005, 200.        ],
#        [199.80000005, 199.6000001 , 199.40020035, ..., 199.40020035,
#         199.6000001 , 199.80000005],
#        [199.6002003 , 199.40020035, 199.2004006 , ..., 199.2004006 ,
#         199.40020035, 199.6002003 ],
#        ...,
#        [199.6002003 , 199.40020035, 199.2004006 , ..., 199.2004006 ,
#         199.40020035, 199.6002003 ],
#        [199.80000005, 199.6000001 , 199.40020035, ..., 199.40020035,
#         199.6000001 , 199.80000005],
#        [200.        , 199.80000005, 199.6002003 , ..., 199.6002003 ,
#         199.80000005, 200.        ]])

# %%
X
# Out:
# array([[-10.        ,  -9.989995  ,  -9.97998999, ...,   9.97998999,
#           9.989995  ,  10.        ],
#        [-10.        ,  -9.989995  ,  -9.97998999, ...,   9.97998999,
#           9.989995  ,  10.        ],
#        [-10.        ,  -9.989995  ,  -9.97998999, ...,   9.97998999,
#           9.989995  ,  10.        ],
#        ...,
#        [-10.        ,  -9.989995  ,  -9.97998999, ...,   9.97998999,
#           9.989995  ,  10.        ],
#        [-10.        ,  -9.989995  ,  -9.97998999, ...,   9.97998999,
#           9.989995  ,  10.        ],
#        [-10.        ,  -9.989995  ,  -9.97998999, ...,   9.97998999,
#           9.989995  ,  10.        ]])

# %%
fig1 = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='hot')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
ax.view_init(45, 0)

fig2 = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='hot')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
ax.view_init(90, 0)
